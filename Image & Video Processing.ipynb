# %%
import cv2

# %%
cap=cv2.VideoCapture(0)  #default camera
print(cap.isOpened())
fourcc=cv2.VideoWriter_fourcc(*'XVID')
out=cv2.VideoWriter('camera output.avi',fourcc,20.0,(640,480))#3rd arg-no. of frames per second
while(True):
    ret,frame=cap.read()#returns true if frame is available and saved in ret,and frame is saved in frame
    if ret==True:
        out.write(frame)
        cv2.imshow('frame',frame)
        #print(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        #print(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        if cv2.waitKey(1)&0xFF==ord('q'):
            break
    else:
        break
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# True

# %%
cap=cv2.VideoCapture(0)    #default camera
while(True):
    ret,frame=cap.read()#returns true if frame is available and saved in ret,and frame is saved in frame
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)#gray scale image
    cv2.imshow('frame',gray)
    if cv2.waitKey(1)&0xFF==ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
cap=cv2.VideoCapture(0)
print(cv2.CAP_PROP_FRAME_WIDTH)
print(cv2.CAP_PROP_FRAME_HEIGHT)
cap.set(3,1208)#width
cap.set(4,720)#height
print(cap.get(3))
print(cap.get(4))
fourcc=cv2.VideoWriter_fourcc(*'XVID')
out=cv2.VideoWriter("camera output.avi",fourcc,20.0,(1200,720))
while(True):
    ret,frame=cap.read()
    if ret==True:
        cv2.imshow('frame',frame)
        out.write(frame)
        if cv2.waitKey(1)&0xFF==ord('q'):
            break
    else:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 3
# 4
# 1280.0
# 720.0

# %%
import cv2
import datetime
cap=cv2.VideoCapture(0)
print(cv2.CAP_PROP_FRAME_WIDTH)
print(cv2.CAP_PROP_FRAME_HEIGHT)
cap.set(3,1020)#width
cap.set(4,780)#height
print(cap.get(3))
print(cap.get(4))
fourcc=cv2.VideoWriter_fourcc(*'XVID')
out=cv2.VideoWriter("camera output.avi",fourcc,20.0,(1200,720))
while(True):
    ret,frame=cap.read()
    if ret==True:
        font=cv2.FONT_HERSHEY_SIMPLEX
        text="Width:"+str(cap.get(3))+ "Height:"+str(cap.get(4))
        date=str(datetime.datetime.now())#putting date and time 
        frame=cv2.putText(frame,text+" | "+date,(10,30),font,1,
                          (0,255,255),1,cv2.LINE_AA)#adding text
        
        cv2.imshow('frame',frame)
        #out.write(frame)
        if cv2.waitKey(1)&0xFF==ord('q'):
            break
    else:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 3
# 4
# 1280.0
# 720.0

# %%
# Out:
# 119  ,  182
# 346  ,  245
# 130  ,  294
# 71  ,  320
# 304  ,  400
# 65  ,  401
# 348  ,  479

# %%
#print(img)
print("Enter s to save a copy of the image and esc to close the image")
cv2.imshow("image",img)
k=cv2.waitKey(0)

if k==27:
    cv2.destroyAllWindows()
elif k==ord('s'):
    cv2.imwrite(file+'lena_copy.png',img)
    cv2.destroyAllWindows()
#flag--->1=color img
#         0=grayscale img
#        -1=same img(no change)
# Out:
# Enter s to save a copy of the image and esc to close the image

# %%
import cv2
#drawing line on an image
file1="E:\\Deep Learning\\opencv-master\\opencv-master\\samples\\data\\"
img1=cv2.imread(file1+"lena.jpg",1)
img1=cv2.line(img1,(0,0),(255,255),(43,255,43))
img1=cv2.arrowedLine(img1,(0,255),(255,255),(43,133,43),5)
img1=cv2.rectangle(img1,(120,80),(180,180),(43,255,43),5)
img1=cv2.rectangle(img1,(120,80),(180,180),(43,255,43),-1)
img1=cv2.circle(img1,(300,350),50,(34,234,123),3)
font=cv2.FONT_HERSHEY_SIMPLEX
img1=cv2.putText(img1,'Lena Ren',(20,500),font,3,(255,255,255),8,cv2.LINE_AA)
cv2.imshow('image',img1)
k=cv2.waitKey(0)
if k==27:
    cv2.destroyAllWindows()
elif k==ord('s'):
    cv2.imwrite(file1+'lena_copy.png',img1)
    cv2.destroyAllWindows()
cv2.destroyAllWindows()

# %%
import cv2
import random
import numpy as np
img1=np.random.randn(512,612,3)
#img1=np.ones([512,512,3],np.uint8)
file1="E:\\Deep Learning\\opencv-master\\opencv-master\\samples\\data\\"
img1=cv2.line(img1,(0,0),(255,255),(43,255,43))
img1=cv2.arrowedLine(img1,(0,255),(255,255),(43,133,43),5)
img1=cv2.rectangle(img1,(120,80),(180,180),(43,255,43),5)
img1=cv2.rectangle(img1,(100,20),(150,50),(43,255,43),-1)
img1=cv2.circle(img1,(300,350),50,(34,234,123),3)
font=cv2.FONT_HERSHEY_SIMPLEX
img1=cv2.putText(img1,'Lena Ren',(20,500),font,3,(255,255,255),8,cv2.LINE_AA)
cv2.imshow('image',img1)
k=cv2.waitKey(0)
if k==27:
    cv2.destroyAllWindows()
elif k==ord('s'):
    cv2.imwrite(file1+'img1.png',img1)
    cv2.destroyAllWindows()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
file="C:\\Users\\sagar\\Desktop\\abstract.jpg"

img1=cv2.imread(file,1)
W=img1.shape
print(W)
img1[170:300,100:200]=img1[270:400,400:500]
cv2.imshow("Abstract",img1)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (480, 852, 3)

# %% [markdown]
# # Mouse Events

# %%
import cv2
import numpy as np
#events=[i for i in dir(cv2) if "EVENT" in i]
#print(events)
def click_event(event,x,y,flags,params):
    if event==cv2.EVENT_LBUTTONDOWN:
        #print(x," , ",y)
        font=cv2.FONT_HERSHEY_SIMPLEX
        text=str(x)+', '+str(y)
        cv2.putText(img,text,(x,y),font,0.5,(15,255,255),1)
        cv2.imshow("image",img)
    if event==cv2.EVENT_RBUTTONDOWN:#print BGR channel on image
        blue=img[y,x,0]
        green=img[y,x,1]
        red=img[y,x,2]
        font=cv2.FONT_HERSHEY_SIMPLEX
        text=str(blue)+', '+str(green)+", "+str(red)
        cv2.putText(img,text,(x,y),font,0.5,(15,255,255),1)
        cv2.imshow("image",img)
#img=np.zeros((512,512,3),np.uint8)
file="C:\\Users\\sagar\\Desktop\\abstract.jpg"
img=cv2.imread(file,1)
cv2.imshow("image",img)
cv2.setMouseCallback("image",click_event)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 845  ,  279
# 825  ,  272
# 806  ,  268
# 782  ,  264
# 763  ,  259
# 739  ,  257
# 712  ,  253
# 691  ,  250
# 674  ,  248
# 658  ,  244
# 644  ,  242
# 630  ,  240
# 619  ,  238
# 611  ,  238
# 604  ,  237
# 599  ,  237
# 596  ,  237
# 593  ,  236
# 592  ,  236
# 591  ,  234
# 590  ,  233
# 586  ,  232
# 575  ,  227
# 561  ,  221
# 544  ,  214
# 525  ,  208
# 508  ,  204
# 494  ,  200
# 478  ,  195
# 466  ,  192
# 457  ,  190
# 451  ,  187
# 446  ,  185
# 442  ,  185
# 436  ,  184
# 433  ,  184
# 431  ,  182
# 430  ,  182
# 428  ,  182
# 427  ,  182
# 426  ,  182
# 426  ,  184
# 426  ,  186
# 426  ,  190
# 426  ,  193
# 426  ,  197
# 426  ,  201
# 427  ,  207
# 427  ,  216
# 429  ,  227
# 431  ,  241
# 432  ,  254
# 434  ,  263
# 436  ,  269
# 437  ,  275
# 439  ,  282
# 439  ,  288
# 440  ,  292
# 442  ,  298
# 443  ,  304
# 445  ,  309
# 446  ,  315
# 446  ,  319
# 448  ,  324
# 448  ,  328
# 448  ,  330
# 449  ,  335
# 449  ,  339
# 450  ,  340
# 450  ,  341
# 450  ,  342
# ...

# %% [markdown]
# # drawing line and circle

# %%
import cv2
import numpy as np
#events=[i for i in dir(cv2) if "EVENT" in i]
#print(events)
def click_event(event,x,y,flags,params):
    if event==cv2.EVENT_LBUTTONDOWN:
        cv2.circle(img,(x,y),20,(15,255,255),-1)
        points.append((x,y))
        if len(points)>=2:
            cv2.line(img,points[-1],points[-2],(15,255,255),3)
        cv2.imshow("image",img)
#img=np.zeros((512,512,3),np.uint8)
file="C:\\Users\\sagar\\Desktop\\abstract.jpg"
img=cv2.imread(file,1)
cv2.imshow("image",img)
points=[]
cv2.setMouseCallback("image",click_event)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # creating new window of a selected color from image

# %%
import cv2
import numpy as np
#events=[i for i in dir(cv2) if "EVENT" in i]
#print(events)
def click_event(event,x,y,flags,params):
    #
    if event==cv2.EVENT_LBUTTONDOWN:
        blue=img[y,x,0]
        green=img[y,x,1]
        red=img[y,x,2]
        cv2.circle(img,(x,y),8,(15,255,255),-1)
        mycolorimage=np.zeros((512,512,3),np.uint8)
        mycolorimage[:]=[blue,green,red]
        cv2.imshow("colored image",mycolorimage)
#img=np.zeros((512,512,3),np.uint8)
file="C:\\Users\\sagar\\Desktop\\abstract.jpg"
img=cv2.imread(file,1)
cv2.imshow("image",img)
points=[]
cv2.setMouseCallback("image",click_event)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Replacing a part of image with another part of same image

# %%
import cv2
import numpy as np
file="E:\\Deep Learning\\opencv-master\\opencv-master\\samples\\data\\"
img=cv2.imread(file+"messi5.jpg",1)
def get_coordinates(event,x,y,flags,params):
    if event==cv2.EVENT_LBUTTONDOWN:
        cood=[x,y]
        print(str(x)+", "+str(y))
        points.append(cood)
        if len(points)==3:
            part=img[points[0][0]:points[0][1],points[1][0]:points[1][1]]
            sh=part.shape
            print(part.shape)
            a=abs(points[0][0]-points[1][0])
            b=abs(points[0][1]-points[1][1])
            print("a:",a)
            print("b:",b)
            p=points[2][0]+a
            q=points[2][1]+b
            #img[points[2][0]:p,points[2][1]:q]=part
            img[10:10+a,40:40+b]=part
            cv2.imshow("image",img)
cv2.imshow("image",img)
points=[]
cv2.setMouseCallback("image",get_coordinates)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 317, 286
# 411, 337

# %% [markdown]
# # Merging two images using Add()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
file="E:\\Deep Learning\\opencv-master\\opencv-master\\samples\\data\\"
img1=cv2.imread(file+"opencv-logo.png")
img=cv2.imread(file+"messi5.jpg")

img=cv2.resize(img,(512,512))
img1=cv2.resize(img1,(512,512))

dst=cv2.add(img,img1)

plt.imshow(dst)
plt.title('my picture')
plt.show()
#cv2.imshow("image",dst)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %% [markdown]
# # cv2.addWeighted()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
file="E:\\Deep Learning\\opencv-master\\opencv-master\\samples\\data\\"
img1=cv2.imread(file+"opencv-logo.png")
img=cv2.imread(file+"messi5.jpg")

img=cv2.resize(img,(512,512))

img1=cv2.resize(img1,(512,512))

dst=cv2.addWeighted(img,.9,img1,.05,.9);


cv2.imshow("image",dst)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 512

# %%
import cv2

# Load the image
image = cv2.imread(file)
# Blur the image
gauss = cv2.GaussianBlur(image, (7,7), 0)
# Apply Unsharp masking
unsharp_image = cv2.addWeighted(image, 2, gauss, -1, 0)

# %% [markdown]
# # Bitwise operations

# %%
import numpy as np
import cv2
img1=np.zeros((256,500,3),np.uint8)
img1=cv2.rectangle(img1,(200,0),(300,100),(255,255,255),-1)
file="E:\\Deep Learning\\opencv-master\\opencv-master\\samples\\data\\"
img2=cv2.imread(file+"cards.png")
img2=cv2.resize(img2,(512,512))
img1=cv2.resize(img1,(512,512))
bitAnd=cv2.bitwise_and(img1,img2)
bitnot=cv2.bitwise_not(img1)
cv2.imshow("image1",img1)
cv2.imshow("image2",img2)
cv2.imshow("Bitwise And Image",bitAnd)
cv2.imshow("Bitwise Not",bitnot)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # TrackBar

# %%
import numpy as np
import cv2 as cv
def nothing(x):
    #print(x)
    pass
img=np.zeros((320,512,3),np.uint8)
cv.namedWindow("image")
cv.createTrackbar('B','image',0,255,nothing)
cv.createTrackbar('G','image',0,255,nothing)
cv.createTrackbar('R','image',0,255,nothing)

switch='0 : OFF\n 1 : ON'
cv.createTrackbar(switch,'image',0,1,nothing)

while(1):
    cv.imshow("image",img)
    k=cv.waitKey(1) & 0xFF
    if k==27:
        break
    b=cv.getTrackbarPos("B",'image')
    g=cv.getTrackbarPos("G",'image')
    r=cv.getTrackbarPos("R",'image')
    s=cv.getTrackbarPos(switch,'image')
    
    if s==0:
        img[:]=0
    else:
        img[:]=[b,g,r]
    
cv.destroyAllWindows()

# %% [markdown]
# # HSV Object Detection

# %%
import cv2
import numpy as np
def nothing(x):
    pass
cv2.namedWindow("Tracking")
cv2.createTrackbar("Lower Hue       :","Tracking",0,255,nothing)
cv2.createTrackbar("Lower Satuartion:","Tracking",0,255,nothing)
cv2.createTrackbar("Lower Value     :","Tracking",0,255,nothing)
cv2.createTrackbar("Upper Hue       :","Tracking",255,255,nothing)
cv2.createTrackbar("Upper Saturation:","Tracking",255,255,nothing)
cv2.createTrackbar("Upper Value     :","Tracking",255,255,nothing)

file="E:\\Deep Learning\\opencv-master\\opencv-master\\samples\\data\\"
while True:
    
    frame=cv2.imread(file+'smarties.png')
    hsv=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
    l_h=cv2.getTrackbarPos("Lower Hue       :","Tracking")
    l_s=cv2.getTrackbarPos("Lower Satuartion:","Tracking")
    l_v=cv2.getTrackbarPos("Lower Value     :","Tracking")
    u_h=cv2.getTrackbarPos("Upper Hue       :","Tracking")
    u_s=cv2.getTrackbarPos("Upper Saturation:","Tracking")
    u_v=cv2.getTrackbarPos("Upper Value     :","Tracking")
    
    l_b=np.array([l_h,l_s,l_v])
    u_b=np.array([u_h,u_s,u_v])
    
    mask=cv2.inRange(hsv,l_b,u_b)
    res=cv2.bitwise_and(frame,frame,mask=mask)
    
    
    cv2.imshow("frame",frame)
    cv2.imshow("mask",mask)
    cv2.imshow("res",res)
    key=cv2.waitKey(1)
    if key==27:
        break
cv2.destroyAllWindows()

# %%
# Object detection for video
import cv2
import numpy as np
def nothing(x):
    pass

cap=cv2.VideoCapture(0)

cv2.namedWindow("Tracking")
cv2.createTrackbar("Lower Hue       :","Tracking",0,255,nothing)
cv2.createTrackbar("Lower Satuartion:","Tracking",0,255,nothing)
cv2.createTrackbar("Lower Value     :","Tracking",0,255,nothing)
cv2.createTrackbar("Upper Hue       :","Tracking",255,255,nothing)
cv2.createTrackbar("Upper Saturation:","Tracking",255,255,nothing)
cv2.createTrackbar("Upper Value     :","Tracking",255,255,nothing)

file="E:\\Deep Learning\\opencv-master\\opencv-master\\samples\\data\\"
while True:
    
    _,frame=cap.read()
    
    hsv=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
    l_h=cv2.getTrackbarPos("Lower Hue       :","Tracking")
    l_s=cv2.getTrackbarPos("Lower Satuartion:","Tracking")
    l_v=cv2.getTrackbarPos("Lower Value     :","Tracking")
    u_h=cv2.getTrackbarPos("Upper Hue       :","Tracking")
    u_s=cv2.getTrackbarPos("Upper Saturation:","Tracking")
    u_v=cv2.getTrackbarPos("Upper Value     :","Tracking")
    
    l_b=np.array([l_h,l_s,l_v])
    u_b=np.array([u_h,u_s,u_v])
    
    mask=cv2.inRange(hsv,l_b,u_b)
    res=cv2.bitwise_and(frame,frame,mask=mask)
    
    
    cv2.imshow("frame",frame)
    cv2.imshow("mask",mask)
    cv2.imshow("res",res)
    key=cv2.waitKey(1)
    if key==27:
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Thresholding an Image

# %%
#background segmentation technique used to segment any object from background
import cv2
import numpy as np

file="E:\\Deep Learning\\opencv-master\\opencv-master\\samples\\data\\"

img=cv2.imread(file+"gradient.png")
_,th1=cv2.threshold(img,127,255,cv2.THRESH_BINARY)
_,th2=cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
_,th3=cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
_,th4=cv2.threshold(img,127,255,cv2.THRESH_TOZERO)

cv2.imshow("image",img)
cv2.imshow("th1",th1)
cv2.imshow("th2",th2)
cv2.imshow("th3",th3)
cv2.imshow("th4",th4)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Adaptive Thresholding

# %%
import cv2
import numpy as np

file="E:\\Deep Learning\\opencv-master\\opencv-master\\samples\\data\\"

img=cv2.imread(file+"sudoku.png",0)
th1=cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,2)
th2=cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,2)

cv2.imshow("image",img)
cv2.imshow("th1",th1)
cv2.imshow("th2",th2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Matplotlib with opencv

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib qt
file="E:\\Deep Learning\\opencv-master\\opencv-master\\samples\\data\\"

img=cv2.imread(file+"sudoku.png",0)
th1=cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,2)
th2=cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,2)

titles=["original image","mean_c","gaussian_c"]
images=[img,th1,th2]
for i in range(3):
    plt.subplot(1,3,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
    
plt.show()

# %% [markdown]
#  # Morphological Transformation

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib qt
file="E:\\Deep Learning\\opencv-master\\opencv-master\\samples\\data\\"

img=cv2.imread(file+"smarties.png",cv2.IMREAD_GRAYSCALE)
_,mask=cv2.threshold(img,220,255,cv2.THRESH_BINARY_INV)

kernal=np.ones((5,5),np.uint8)
dilation=cv2.dilate(mask,kernal,iterations=2)
erosion=cv2.erode(mask,kernal,iterations=4)
opening=cv2.morphologyEx(mask,cv2.MORPH_OPEN,kernal)#erosion is 1st occured and then erosion
closing=cv2.morphologyEx(mask,cv2.MORPH_CLOSE,kernal)#dilation is 1st occured and then dilation
mg=cv2.morphologyEx(mask,cv2.MORPH_GRADIENT,kernal)
th=cv2.morphologyEx(mask,cv2.MORPH_TOPHAT,kernal)



titles=['image','mask','dilation','erosion','opening','closing','mg','th']
images=[img,mask,dilation,erosion,opening,closing,mg,th]

for i in range(8):
    plt.subplot(2,4,i+1), plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# # Smoothing and Blurring For Reducing Noise of an Image

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib qt
file="E:\\Deep Learning\\opencv-master\\opencv-master\\samples\\data\\"

#img=cv2.imread(file+"opencv-logo.png")
#img=cv2.imread(file+"imageTextR.png")

img=cv2.imread(file+"messi5.jpg")
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

kernal=np.ones((5,5),np.float32)/25
dst=cv2.filter2D(img,-1,kernal)
blur=cv2.blur(img,(5,5))
gblur=cv2.GaussianBlur(img,(5,5),10)
median=cv2.medianBlur(img,5)
bilateral=cv2.bilateralFilter(img,9,75,75)

titles=['image','2D Convolution','blur','Gaussian Blur','median','bilateral']

images=[img,dst,blur,gblur,median,bilateral]

for i in range(6):
    plt.subplot(2,3,i+1), plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# # Image Gradients And Canny Edge Detection

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib qt
file="E:\\Deep Learning\\opencv-master\\opencv-master\\samples\\data\\"

#img=cv2.imread(file+"opencv-logo.png")
img=cv2.imread(file+"messi5.jpg",cv2.IMREAD_GRAYSCALE)
#img=cv2.imread(file+"sudoku.png",cv2.IMREAD_GRAYSCALE)

lap=cv2.Laplacian(img,cv2.CV_64F,ksize=1)
lap=np.uint8(np.absolute(lap))
sobelx=cv2.Sobel(img,cv2.CV_64F,1,0)
sobely=cv2.Sobel(img,cv2.CV_64F,0,1)
sobelx=np.uint8(np.absolute(sobelx))
sobely=np.uint8(np.absolute(sobely))
sobelcombined=cv2.bitwise_or(sobelx,sobely)
canny=cv2.Canny(img,100,200)

titles=['image','laplacian','sobelx','sobely','sobelcombined','canny']
images=[img,lap,sobelx,sobely,sobelcombined,canny]

for i in range(6):
    plt.subplot(2,3,i+1), plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# # Canny Edge Detection
#     It is an edge detection operator that uses a multi-stage algorithm to detect a wide range of edges in images.
#     It was developed by JOHN F. CANNY in 1986.
#     It is composed of 5 steps:
#     1. Noise reduction
#     2. Gradient Calculation
#     3. Non-maximum suppression
#     4. Double threshold
#     5. Edge tracking by Hysteresis

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib qt
file="E:\\Deep Learning\\opencv-master\\opencv-master\\samples\\data\\"

#img=cv2.imread(file+"opencv-logo.png")
#img=cv2.imread(file+"imageTextR.png")
img=cv2.imread(file+"messi5.jpg",0)

canny=cv2.Canny(img,50,50)


titles=['image','canny']
images=[img,canny]

for i in range(2):
    plt.subplot(1,2,i+1), plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# # Image Pyramids for adjusting resolution

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib qt
file="E:\\Deep Learning\\opencv-master\\opencv-master\\samples\\data\\"

#img=cv2.imread(file+"opencv-logo.png")
#img=cv2.imread(file+"imageTextR.png")
img=cv2.imread(file+"messi5.jpg",1)
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

lr=cv2.pyrDown(img)
lr2=cv2.pyrDown(lr)
hr2=cv2.pyrUp(lr2)


titles=['image','PyrDown Image','PyrDown 2','PyrDown 3']
images=[img,lr,lr2,hr2]

for i in range(4):
    plt.subplot(2,2,i+1), plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
file="E:\\Deep Learning\\opencv-master\\opencv-master\\samples\\data\\"

#img=cv2.imread(file+"opencv-logo.png")
#img=cv2.imread(file+"imageTextR.png")
img=cv2.imread(file+"lena.jpg")

layer=img.copy()
gp=[layer]

for i in range(6):
    layer=cv2.pyrDown(layer)
    gp.append(layer)
    #cv2.imshow(str(i),layer)

layer=gp[5]
cv2.imshow('Upper level Gaussian Pyramid',layer)
lp=[layer]
for i in range(5,0,-1):
    gaussian_extended=cv2.pyrUp(gp[i])
    laplacian=cv2.subtract(gp[i-1],gaussian_extended)
    cv2.imshow(str(i),laplacian)

cv2.imshow("original image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Image Blending and Reconstruction using Laplacian and Gaussian Pyramid

# %%
import cv2
import numpy as np
file="E:\\Deep Learning\\opencv-master\\opencv-master\\samples\\data\\"

#img=cv2.imread(file+"opencv-logo.png")
orange=cv2.imread(file+"orange.jpg")
apple=cv2.imread(file+"apple.jpg")

apple_orange=np.hstack((apple[:,:256],orange[:,256:]))
#generate gaussian pyramid for apple
apple_copy=apple.copy()
gp_apple=[apple_copy]
for i in range(6):
    apple_copy=cv2.pyrDown(apple_copy)
    gp_apple.append(apple_copy)

#generate gaussian pyramid for orange
orange_copy=orange.copy()
gp_orange=[orange_copy]
for i in range(6):
    orange_copy=cv2.pyrDown(orange_copy)
    gp_orange.append(orange_copy)
#generate laplacian pyramid for apple 
apple_copy=gp_apple[5]
lp_apple=[apple_copy]
for i in range(5,0,-1):
    gaussian_extended=cv2.pyrUp(gp_apple[i])
    laplacian=cv2.subtract(gp_apple[i-1],gaussian_extended)
    lp_apple.append(laplacian)

#generate laplacian pyramid for orange 
orange_copy=gp_orange[5]
lp_orange=[orange_copy]

for i in range(5,0,-1):
    gaussian_extended=cv2.pyrUp(gp_orange[i])
    laplacian=cv2.subtract(gp_orange[i-1],gaussian_extended)
    lp_orange.append(laplacian)
# Now add left and right of images in each layer
apple_orange_pyramid=[]
n=0
for apple_lap,orange_lap in zip(lp_apple,lp_orange):
    n+=1
    cols,rows,ch=apple_lap.shape
    laplacian=np.hstack((apple_lap[:,0:int(cols/2)],orange_lap[:,int(cols/2):]))
    apple_orange_pyramid.append(laplacian)
#now reconstruct
apple_orange_reconstruct=apple_orange_pyramid[0]
for i in range(1,6):
    apple_orange_reconstruct=cv2.pyrUp(apple_orange_reconstruct)
    apple_orange_reconstruct=cv2.add(apple_orange_pyramid[i],apple_orange_reconstruct)
cv2.imshow("apple",apple)
cv2.imshow("orange",orange)
cv2.imshow("apple and orange",apple_orange)
cv2.imshow("apple and orange Blended",apple_orange_reconstruct)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Brightness and Contrast

# %%
from __future__ import print_function
from builtins import input
import cv2 as cv
import numpy as np
import argparse
# Read image given by user
parser = argparse.ArgumentParser(description='Code for Changing the contrast and brightness of an image! tutorial.')
parser.add_argument('--input', help='Path to input image.', default='lena.jpg')
args = parser.parse_args()
image = cv.imread("E:\\Deep Learning\\opencv-master\\opencv-master\\samples\\data\\lena.jpg")
if image is None:
    print('Could not open or find the image: ', args.input)
    exit(0)
new_image = np.zeros(image.shape, image.dtype)
alpha = 1.0 # Simple contrast control
beta = 0    # Simple brightness control
# Initialize values
print(' Basic Linear Transforms ')
print('-------------------------')
try:
    alpha = float(input('* Enter the alpha value [1.0-3.0]: '))
    beta = int(input('* Enter the beta value [0-100]: '))
except ValueError:
    print('Error, not a number')

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image[y,x,c] = np.clip(alpha*image[y,x,c] + beta, 0, 255)
cv.imshow('Original Image', image)
cv.imshow('New Image', new_image)
# Wait until user press some key
cv.waitKey()
# Out:
# usage: ipykernel_launcher.py [-h] [--input INPUT]
# ipykernel_launcher.py: error: unrecognized arguments: -f C:\Users\sagar\AppData\Roaming\jupyter\runtime\kernel-5a420fde-a9fe-4e45-a1ab-1a12369a9cac.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# C:\Users\sagar\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2971: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# # Contours (Detects edges)

# %%
import numpy as np
import cv2

file="E:\\Deep Learning\\opencv-master\\opencv-master\\samples\\data\\"
img=cv2.imread(file+"messi5.jpg")

imgray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret,thresh=cv2.threshold(imgray,127,255,0)
contours,heirarchy=cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
print("No. of contours: ",len(contours))

cv2.drawContours(img,contours,700,(0,255,0),1)# draws all the contours
#cv2.drawContours(img,contours,1,(0,255,0),3)# draws a particular conntours

cv2.imshow('Image',img)
cv2.imshow('IMAGE GRAY',imgray)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# No. of contours:  787

# %% [markdown]
# # Motion Detector

# %%
import cv2
import numpy as np
file="E:\\Deep Learning\\opencv-master\\opencv-master\\samples\\data\\"

cap=cv2.VideoCapture(file+'vtest.avi')
#cap=cv2.VideoCapture(0)
ret,frame1=cap.read()
ret,frame2=cap.read()

while cap.isOpened():
    diff=cv2.absdiff(frame1,frame2)
    
    gray=cv2.cvtColor(diff,cv2.COLOR_BGR2GRAY)
    blur=cv2.GaussianBlur(gray,(5,5),0)
    _,thresh=cv2.threshold(blur,20,255,cv2.THRESH_BINARY)
    dilated=cv2.dilate(thresh,None,iterations=3)
    contours,_=cv2.findContours(dilated,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    
    #cv2.drawContours(frame1,contours,-1,(0,255,0),1)
    
    for contour in contours:
        (x,y,w,h)=cv2.boundingRect(contour)
        if cv2.contourArea(contour)<700:
            continue
        cv2.rectangle(frame1,(x,y),(x+w,y+h),(15,255,255),2)
        cv2.putText(frame,"Status: {}".format('Movement'),(10,20),cv2.FONT_HERSHEY_SIMPLEX,1,(15,255,255),1)
    cv2.imshow("feed",frame1)
    frame1=frame2
    ret,frame2=cap.read() 
    
    if cv2.waitKey(40)==27:
        break
        
cv2.destroyAllWindows()
cap.release()

# %% [markdown]
# # Detecting Geometric Shapes

# %%
import numpy as np
import cv2

file="E:\\Deep Learning\\opencv-master\\opencv-master\\samples\\data\\"
img=cv2.imread(file+"pic1.png")
imgGrey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, thrash = cv2.threshold(imgGrey, 240, 255, cv2.THRESH_BINARY)
contours, _ = cv2.findContours(thrash, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

cv2.imshow("img", img)
for contour in contours:
    approx = cv2.approxPolyDP(contour, 0.01* cv2.arcLength(contour, True), True)
    cv2.drawContours(img, [approx], 0, (0, 0, 0), 5)
    x = approx.ravel()[0]
    y = approx.ravel()[1] - 5
    if len(approx) == 3:
        cv2.putText(img, "Triangle", (x, y), cv2.FONT_HERSHEY_COMPLEX, 0.5, (0, 0, 0))
    elif len(approx) == 4:
        x1 ,y1, w, h = cv2.boundingRect(approx)
        aspectRatio = float(w)/h
        print(aspectRatio)
        if aspectRatio >= 0.95 and aspectRatio <= 1.05:
          cv2.putText(img, "square", (x, y), cv2.FONT_HERSHEY_COMPLEX, 0.5, (0, 0, 0))
        else:
          cv2.putText(img, "rectangle", (x, y), cv2.FONT_HERSHEY_COMPLEX, 0.5, (0, 0, 0))
    elif len(approx) == 5:
        cv2.putText(img, "Pentagon", (x, y), cv2.FONT_HERSHEY_COMPLEX, 0.5, (0, 0, 0))
    elif len(approx) == 10:
        cv2.putText(img, "Star", (x, y), cv2.FONT_HERSHEY_COMPLEX, 0.5, (0, 0, 0))
    else:
        cv2.putText(img, "Circle", (x, y), cv2.FONT_HERSHEY_COMPLEX, 0.5, (0, 0, 0))


cv2.imshow("shapes", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1.3333333333333333
# 0.9387755102040817
# 1.8018867924528301

# %% [markdown]
# # Asciify a Picture

# %%
from PIL import Image ,ImageDraw,ImageFont
import math
import cv2

# %%
chars="!@#$%^&*()QWERTYUIOPASDFGHJKLMNZBXCVhsjdhdhdyeteendhdkwtquwiei,<>?{}[]:-+.*/"[::-1]
#chars="!@#$%^&*()qwertyuioplkjhgfdsazxcvDFDDGFGFFHRDWWRTYHDDGMBCXZAQWERTIP_+=/*-+.:{}[]|"
charArray=list(chars)
charLength=len(charArray)
interval=charLength/256

scalefactor=0.1
charwidth=15
charheight=15

# %%
def getChar(input1):
    return charArray[math.floor(input1*interval)]

# %%
def asciifyImage(ImageFile):
    text_file=open('outputAscii.txt','w')
    image=Image.open(ImageFile)
    fontoutput=ImageFont.truetype("C:\\Windows\\Fonts\\arial.ttf",15)
    
    width,height=image.size
    image.resize((int(scalefactor*width),int(scalefactor*height*(charwidth/charheight))),Image.NEAREST)
    width,height=image.size
    pixel=image.load()
    
    outputimage=Image.new('RGB',(charwidth*width,charheight*height),color=(0,0,0))
    drawing=ImageDraw.Draw(outputimage)
    for i in range(height):
        for j in range(width):
            r,g,b=pixel[j,i]
            h=int((r+g+b)/3)
            pixel[j,i]=(h,h,h)
            text_file.write(getChar(h))
            drawing.text((j*charwidth,i*charheight),getChar(h),font=fontoutput,fill=(r,g,b))
        text_file.write('\n')
    outputimage.save('F:\\My Edited Images\\yuvia2.jpg')
    
asciifyImage("F:\\My Edited Images\\yuvia.jpg")
